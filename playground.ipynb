# %% [markdown]
# Scatterplot testing

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

# path = "__.xlsx"
# df = pd.read_excel(path)

x = np.array([2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022])
y = np.array([10753992000, 10705452000, 10544122000, 10514853000, 10436626000, 10154668000, 10604732000, 10208674000, 9672364000, 9800375000, 9768296000])

res = stats.linregress(x, y)
print(f"R-squared: {res.rvalue**2:.6f}")

# Perform linear regression
fit1 = stats.linregress(x, y)

# Use the slope and intercept to construct the best fit line
y_pred = fit1.intercept + fit1.slope * x

# Plotting the data points
plt.scatter(x, y, color='blue', label='Data points')

# Plotting the best fit line
plt.plot(x, y_pred, color='red', label=f'Best fit line: y={fit1.slope:.2f}x+{fit1.intercept:.2f}')

# Adding the legend
plt.legend()
plt.show()
# Out:
# R-squared: 0.794527

# %%
import numpy as np
from scipy.stats import pearsonr

def tsv_to_numpy(file_path):
    """
    Reads a tab-separated file and converts it to a NumPy array.

    Args:
        file_path (str): The path to the TSV file.
        skip_header (bool, optional): Whether to skip the header row. Defaults to False.

    Returns:
        numpy.ndarray: A NumPy array containing the data from the TSV file.
                       Returns None if an error occurs during file reading.
    """
    try:
        data_array = np.loadtxt(file_path, delimiter='\t')
        return data_array
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

# Example usage:
years_array = np.flip(tsv_to_numpy("years.tsv"))
temps_memphis_array = np.flip(tsv_to_numpy("temps_memphis.tsv"))

# corr, _ = pearsonr(years_array, temps_memphis_array)
# print(corr)
# # Plotting the data points
# plt.scatter(years_array, temps_memphis_array, color='blue', label='Data points')
# # Adding the legend
# plt.legend()
# plt.show()

plt.hist(temps_memphis_array, bins=20, color='skyblue', edgecolor='black')
# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Memphis Highest Temperature Distribution in Celsius')

# Display the histogram
plt.show()
